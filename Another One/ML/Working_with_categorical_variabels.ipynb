# %%
import pandas as pd

# %%
fp=pd.read_csv('GPA_data.csv')

# %%
fp
# Out:
#        ID  Gender  Age Extra_Curricular  Study_Hours  Annual_Income  \
# 0    8867    Male   22        Societies           10        1318792
# 1    1316  Female   24        Societies            9         874657
# 2    9443    Male   22        Societies           15        1098331
# 3    1829  Female   25               No            9        1680585
# 4    1989    Male   26               No            7        1361560
# ..    ...     ...  ...              ...          ...            ...
# 995  5129  Female   22               No            5        1675219
# 996  2365    Male   24               No            8         947439
# 997  5140    Male   26           Sports            6        1912975
# 998  4976    Male   22        Societies           12         341543
# 999  6398    Male   23               No           12         975142
#
#      Distance_From_Home   GPA
# 0                   154  1.76
# 1                   181  3.88
# 2                    94  1.73
# ...

# %%
fp.isnull().sum()
# Out:
# ID                    0
# Gender                0
# Age                   0
# Extra_Curricular      0
# Study_Hours           0
# Annual_Income         0
# Distance_From_Home    0
# GPA                   0
# dtype: int64

# %%
fp.describe()
# Out:
#                 ID          Age  Study_Hours  Annual_Income  \
# count  1000.000000  1000.000000  1000.000000   1.000000e+03
# mean   5407.002000    23.946000     9.878000   1.066839e+06
# std    2610.638258     1.988728     3.148496   5.417913e+05
# min    1012.000000    21.000000     5.000000   1.005000e+05
# 25%    3088.500000    22.000000     7.000000   6.092325e+05
# 50%    5338.500000    24.000000    10.000000   1.081010e+06
# 75%    7645.750000    26.000000    13.000000   1.521934e+06
# max    9993.000000    27.000000    15.000000   1.998360e+06
#
#        Distance_From_Home          GPA
# count         1000.000000  1000.000000
# mean            99.487000     2.496410
# std             54.989796     0.869429
# min              5.000000     1.000000
# 25%             52.000000     1.750000
# 50%             98.000000     2.500000
# 75%            143.000000     3.240000
# max            200.000000     4.000000

# %%
fp.drop('ID',axis=1,inplace=True)

# %%
fp[['Gender','Extra_Curricular']]
# Out:
#      Gender Extra_Curricular
# 0      Male        Societies
# 1    Female        Societies
# 2      Male        Societies
# 3    Female               No
# 4      Male               No
# ..      ...              ...
# 995  Female               No
# 996    Male               No
# 997    Male           Sports
# 998    Male        Societies
# 999    Male               No
#
# [1000 rows x 2 columns]

# %%
pd.get_dummies(fp[['Gender','Extra_Curricular']]) #convert to dummy varibles
# Out:
#      Gender_Female  Gender_Male  Extra_Curricular_No  \
# 0            False         True                False
# 1             True        False                False
# 2            False         True                False
# 3             True        False                 True
# 4            False         True                 True
# ..             ...          ...                  ...
# 995           True        False                 True
# 996          False         True                 True
# 997          False         True                False
# 998          False         True                False
# 999          False         True                 True
#
#      Extra_Curricular_Societies  Extra_Curricular_Sports
# 0                          True                    False
# 1                          True                    False
# 2                          True                    False
# 3                         False                    False
# ...

# %%
dummy=pd.get_dummies(fp[['Gender','Extra_Curricular']]).astype(int)
#convert true false to 1,0
dummy
# Out:
#      Gender_Female  Gender_Male  Extra_Curricular_No  \
# 0                0            1                    0
# 1                1            0                    0
# 2                0            1                    0
# 3                1            0                    1
# 4                0            1                    1
# ..             ...          ...                  ...
# 995              1            0                    1
# 996              0            1                    1
# 997              0            1                    0
# 998              0            1                    0
# 999              0            1                    1
#
#      Extra_Curricular_Societies  Extra_Curricular_Sports
# 0                             1                        0
# 1                             1                        0
# 2                             1                        0
# 3                             0                        0
# ...

# %%
dummy.drop(['Gender_Female','Extra_Curricular_No'],axis=1,inplace=True)
dummy.head()
# Out:
#    Gender_Male  Extra_Curricular_Societies  Extra_Curricular_Sports
# 0            1                           1                        0
# 1            0                           1                        0
# 2            1                           1                        0
# 3            0                           0                        0
# 4            1                           0                        0

# %%
fp.drop(['Gender','Extra_Curricular'],axis=1,inplace=True)
#remove two categoris from the original variable i order to add dummy variables
fp.head()
# Out:
#    Age  Study_Hours  Annual_Income  Distance_From_Home   GPA
# 0   22           10        1318792                 154  1.76
# 1   24            9         874657                 181  3.88
# 2   22           15        1098331                  94  1.73
# 3   25            9        1680585                   8  1.29
# 4   26            7        1361560                 122  3.19

# %%
data_new=pd.concat([fp,dummy],axis=1)#adding columns together
data_new.head()
# Out:
#    Age  Study_Hours  Annual_Income  Distance_From_Home   GPA  Gender_Male  \
# 0   22           10        1318792                 154  1.76            1
# 1   24            9         874657                 181  3.88            0
# 2   22           15        1098331                  94  1.73            1
# 3   25            9        1680585                   8  1.29            0
# 4   26            7        1361560                 122  3.19            1
#
#    Extra_Curricular_Societies  Extra_Curricular_Sports
# 0                           1                        0
# 1                           1                        0
# 2                           1                        0
# 3                           0                        0
# 4                           0                        0
