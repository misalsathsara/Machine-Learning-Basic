# %% [markdown]
# Pandas - Working with dataframe and structures

# %%
import numpy as np
import pandas as pd

# %%
d={'Name':['kasun','sunil','mahesh'],'Age':[27, 35, 34]}

# %%
print(d)
# Out:
# {'Name': ['kasun', 'sunil', 'mahesh'], 'Age': [27, 35, 34]}

# %%
df = pd.DataFrame(d) #convert the dictionary into data Frame
print(df)
# Out:
#      Name  Age
# 0   kasun   27
# 1   sunil   35
# 2  mahesh   34

# %%
fp = pd.read_csv('iris.csv')
print(fp)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
print(fp.head())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
print(fp.tail())
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
fp.info() #getting the information about the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df2=pd.DataFrame({'COL1':[12,13,14,15,16],'COL2':[17,18,19,20,21],'COL3':[22,23,24,25,26]})
print(df2)
# Out:
#    COL1  COL2  COL3
# 0    12    17    22
# 1    13    18    23
# 2    14    19    24
# 3    15    20    25
# 4    16    21    26

# %%
df2.to_csv('output.csv',index=False)#writing the data frame to csv
df2.to_excel('output.xlsx',index=False)#writing to an exel file
df2.to_json('output.json')#writing to a json file

# %%
df2['COL1']#accesing a coloumn
# Out:
# 0    12
# 1    13
# 2    14
# 3    15
# 4    16
# Name: COL1, dtype: int64

# %%
df2[1,2]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: (1, 2)
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-2e67eadc1334> in <cell line: 0>()
# ----> 1 df2[1,2]
#
# ...

# %%
df2.iloc[1,2]#using iloc for accesing an element
# Out:
# 23

# %%
df3=pd.DataFrame({'Name':['A','B','C'],'Age':[17,18,19],'Result':['Pass','Fail','Fail']},index=['a','b','c'])
print(df3)
# Out:
#   Name  Age Result
# a    A   17   Pass
# b    B   18   Fail
# c    C   19   Fail

# %%
df3.drop('a')#temperory remiving a row
# Out:
#   Name  Age Result
# b    B   18   Fail
# c    C   19   Fail

# %%
df3
# Out:
#   Name  Age Result
# a    A   17   Pass
# b    B   18   Fail
# c    C   19   Fail

# %%
df3.drop('a',inplace=True)#permanent remiving a row

# %%
df3
# Out:
#   Name  Age Result
# b    B   18   Fail
# c    C   19   Fail

# %%
df3.drop('Age',axis=1)#temperory removing a column
# Out:
#   Name Result
# b    B   Fail
# c    C   Fail

# %%
df3.drop('Age',axis=1,inplace=True)#permanent removing a column

# %%
df3
# Out:
#   Name Result
# b    B   Fail
# c    C   Fail

# %%
df1=pd.DataFrame(np.random.random((5,2)),columns=['A','B'])#create Random Data Frame
df2=pd.DataFrame(np.random.random((5,2)),columns=['A','B'])#create Random Data Frame
df3=pd.DataFrame(np.random.random((5,2)),columns=['E','F'])#create Random Data Frame
print(df1)
print(df2)
print(df3)
# Out:
#           A         B
# 0  0.687439  0.078319
# 1  0.034319  0.908739
# 2  0.960140  0.646683
# 3  0.202589  0.367031
# 4  0.748105  0.856470
#           A         B
# 0  0.947109  0.910632
# 1  0.269516  0.887362
# 2  0.526748  0.507154
# 3  0.617673  0.440811
# 4  0.900949  0.176407
#           E         F
# 0  0.551966  0.116095
# 1  0.963610  0.873147
# 2  0.319280  0.708918
# 3  0.724349  0.748958
# 4  0.865123  0.450015

# %%
pd.concat([df1,df2])#row wise addition:
# Out:
#           A         B
# 0  0.687439  0.078319
# 1  0.034319  0.908739
# 2  0.960140  0.646683
# 3  0.202589  0.367031
# 4  0.748105  0.856470
# 0  0.947109  0.910632
# 1  0.269516  0.887362
# 2  0.526748  0.507154
# 3  0.617673  0.440811
# 4  0.900949  0.176407

# %%
pd.concat([df1,df2],ignore_index=True)ignore_index=True arranging indexes accordingly
# Out:
#           A         B
# 0  0.687439  0.078319
# 1  0.034319  0.908739
# 2  0.960140  0.646683
# 3  0.202589  0.367031
# 4  0.748105  0.856470
# 5  0.947109  0.910632
# 6  0.269516  0.887362
# 7  0.526748  0.507154
# 8  0.617673  0.440811
# 9  0.900949  0.176407

# %%
pd.concat([df1,df3],axis=1) #column wise addition
# Out:
#           A         B         E         F
# 0  0.687439  0.078319  0.551966  0.116095
# 1  0.034319  0.908739  0.963610  0.873147
# 2  0.960140  0.646683  0.319280  0.708918
# 3  0.202589  0.367031  0.724349  0.748958
# 4  0.748105  0.856470  0.865123  0.450015

# %%
pd.value_counts(fp['species'])
# Out:
# <ipython-input-56-3c27377bdddf>:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pd.value_counts(fp['species'])
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
df5=pd.DataFrame({
    'A':[1,2,None,4,],
    'B':[None,2,3,4],
    'C':[1,None,None,4]
})
print(df5)
# Out:
#      A    B    C
# 0  1.0  NaN  1.0
# 1  2.0  2.0  NaN
# 2  NaN  3.0  NaN
# 3  4.0  4.0  4.0

# %%
df5.isnull()
# Out:
#        A      B      C
# 0  False   True  False
# 1  False  False   True
# 2   True  False   True
# 3  False  False  False

# %%
total_nulls=df5.isnull().sum().sum() #count the toatal null values
print(total_nulls)
# Out:
# 4

# %%
#count nulls per column
df5.isnull().sum()
# Out:
# A    1
# B    1
# C    2
# dtype: int64

# %%
df5.dropna()#remove rows with null values
# Out:
#      A    B    C
# 3  4.0  4.0  4.0

# %%
a=df5.fillna(1)#fill null values with 0
print(a)
# Out:
#      A    B    C
# 0  1.0  1.0  1.0
# 1  2.0  2.0  1.0
# 2  1.0  3.0  1.0
# 3  4.0  4.0  4.0

# %% [markdown]
# # **Replace null values with mean value of Columns**

# %%
#replace NaN with mean value of column qnd save it as new dataframe
df6=df5.fillna(df5.mean())
print(df6)
# Out:
#           A    B    C
# 0  1.000000  3.0  1.0
# 1  2.000000  2.0  2.5
# 2  2.333333  3.0  2.5
# 3  4.000000  4.0  4.0

# %%
#create the dictionary with the data
data={
    'Name':['Alice','Bob','Charlie','David','Eve','Frank'],
    'Age':[24,30,22,35,28,40],
}
#create the dtaframe
df1=pd.DataFrame(data)
#display the dataframe
print(df1)
# Out:
#       Name  Age
# 0    Alice   24
# 1      Bob   30
# 2  Charlie   22
# 3    David   35
# 4      Eve   28
# 5    Frank   40

# %% [markdown]
# **Filter and Modify Data**

# %%
filtered_df= df1[df1['Age']>30] #select rows where age is greater than 30
print("Rows where age is greter than 30; ")
print(filtered_df)
# Out:
# Rows where age is greter than 30;
#     Name  Age
# 3  David   35
# 5  Frank   40

# %%
df1['Name']=df1['Name'].str.upper()#convert the name column to uppercase
df1['Age']=df1['Age']+1 #increment the age by 1
print(df1)
# Out:
#       Name  Age
# 0    ALICE   25
# 1      BOB   31
# 2  CHARLIE   23
# 3    DAVID   36
# 4      EVE   29
# 5    FRANK   41

# %%
df1.columns
# Out:
# Index(['Name', 'Age'], dtype='object')
