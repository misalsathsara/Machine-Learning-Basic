# %%
import warnings
warnings.filterwarnings("ignore")
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %%
df = pd.DataFrame(pd.read_csv('datasets/Fuel_Consumption.csv'))

# %%
df.head()
# Out:
#    Year   MAKE    MODEL VEHICLE CLASS  ENGINE SIZE  CYLINDERS TRANSMISSION  \
# 0  2000  ACURA    1.6EL       COMPACT          1.6          4           A4
# 1  2000  ACURA    1.6EL       COMPACT          1.6          4           M5
# 2  2000  ACURA    3.2TL      MID-SIZE          3.2          6          AS5
# 3  2000  ACURA    3.5RL      MID-SIZE          3.5          6           A4
# 4  2000  ACURA  INTEGRA    SUBCOMPACT          1.8          4           A4
#
#   FUEL  FUEL CONSUMPTION  COEMISSIONS
# 0    X              10.5           216
# 1    X               9.8           205
# 2    Z              13.7           265
# 3    Z              15.0           301
# 4    X              11.4           230

# %%
# identify categorical columns
categorical_columns = ['MAKE', 'MODEL', 'VEHICLE CLASS', 'TRANSMISSION', 'FUEL']

# Apply Label encoding

label_encoders = {}

for col in categorical_columns:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])
    label_encoders[col] = le

# %%
df.head()
# Out:
#    Year  MAKE  MODEL  VEHICLE CLASS  ENGINE SIZE  CYLINDERS  TRANSMISSION  \
# 0  2000     0      0              0          1.6          4             1
# 1  2000     0      0              0          1.6          4             6
# 2  2000     0      1              2          3.2          6             4
# 3  2000     0      2              2          3.5          6             1
# 4  2000     0    164              9          1.8          4             1
#
#    FUEL  FUEL CONSUMPTION  COEMISSIONS
# 0     3              10.5           216
# 1     3               9.8           205
# 2     4              13.7           265
# 3     4              15.0           301
# 4     3              11.4           230

# %%
# Define features and target variable
x = df.drop(['FUEL CONSUMPTION'], axis=1)
y = df['FUEL CONSUMPTION']

# %%
# split the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=100)

# %%
# train the model
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
# make predictions on the test set
y_pred = model.predict(x_test)

# %%
# evaluate the model
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
print(f"Mean Squared Error: {mse}")
print(f"R-squared: {r2}")
# Out:
# Mean Squared Error: 0.1391504021832355
# R-squared: 0.9852186331063967

# %% [markdown]
# **Using Decision Tree Classifier**

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report

# %%
# Define features and target variable
y = df['FUEL']  
x = df.drop(['FUEL'], axis=1)

# %%
# split the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=100)

# %%
# train the model
model = DecisionTreeClassifier(random_state=100)    
model.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=100)

# %%
# make predictions on the test set
y_pred = model.predict(x_test)

# %%
# evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy}")
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.9296875
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.67      1.00      0.80         2
#            3       0.96      0.95      0.95        99
#            4       0.85      0.85      0.85        27
#
#     accuracy                           0.93       128
#    macro avg       0.83      0.93      0.87       128
# weighted avg       0.93      0.93      0.93       128

# %%
# Trim spaces from column names
df.columns = df.columns.str.strip()

# %%
# Make a prediction for new data
new_data = pd.DataFrame({
    "Year": [2000],
    "MAKE": ["ACURA"],
    "MODEL": ["1.6EL"],
    "VEHICLE CLASS": ["COMPACT"],
    "ENGINE SIZE": [1.6],
    "CYLINDERS": [4],
    "TRANSMISSION": ["A4"],
    "FUEL CONSUMPTION": [10],
    "COEMISSIONS ": [216]
})

# Apply label encoding to the categorical columns
for col in categorical_columns:
    if col != "FUEL":  # Skip FUEL since it's not in our features anymore
        new_data[col] = label_encoders[col].transform(new_data[col])

# Make prediction
prediction = model.predict(new_data)
print(f"Predicted Fuel Type: {label_encoders['FUEL'].inverse_transform(prediction)[0]}")
# Out:
# Predicted Fuel Type: X

# %% [markdown]
# **Another Method**

# %%
x1 = df.drop(['COEMISSIONS'], axis=1)
y1 = pd.qcut(df['COEMISSIONS'], q=3, labels=['low', 'medium', 'high'])

# %%
# split the data into training and testing sets
x1_train, x1_test, y1_train, y1_test = train_test_split(x1, y1, test_size=0.2, random_state=100)

# %%
# train the model
model1 = DecisionTreeClassifier(random_state=100)
model1.fit(x1_train, y1_train)
# Out:
# DecisionTreeClassifier(random_state=100)

# %%
# make predictions on the test set
y1_pred = model1.predict(x1_test)

# %%
# evaluate the model
accuracy = accuracy_score(y1_test, y1_pred)
print(f"Accuracy: {accuracy}")
print("\nClassification Report:")
print(classification_report(y1_test, y1_pred))
# Out:
# Accuracy: 0.984375
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         high       0.98      0.98      0.98        43
#          low       1.00      1.00      1.00        50
#       medium       0.97      0.97      0.97        35
#
#     accuracy                           0.98       128
#    macro avg       0.98      0.98      0.98       128
# weighted avg       0.98      0.98      0.98       128

# %%
# To check the Label assigned
for col, le in label_encoders.items():
    print(f"Lables for {col}:")
    print(dict(zip(le.classes_, le.transform(le.classes_))))
    print()
# Out:
# Lables for MAKE:
# {'ACURA': 0, 'AUDI': 1, 'BMW': 2, 'BUICK': 3, 'CADILLAC': 4, 'CHEVROLET': 5, 'CHRYSLER': 6, 'DAEWOO': 7, 'DODGE': 8, 'FERRARI': 9, 'FORD': 10, 'GMC': 11, 'HONDA': 12, 'HYUNDAI': 13, 'INFINITI': 14, 'ISUZU': 15, 'JAGUAR': 16, 'JEEP': 17, 'KIA': 18, 'LAND ROVER': 19, 'LEXUS': 20, 'LINCOLN': 21, 'MAZDA': 22, 'MERCEDES-BENZ': 23, 'NISSAN': 24, 'OLDSMOBILE': 25, 'PLYMOUTH': 26, 'PONTIAC': 27, 'PORSCHE': 28, 'SAAB': 29, 'SATURN': 30, 'SUBARU': 31, 'SUZUKI': 32, 'TOYOTA': 33, 'VOLKSWAGEN': 34, 'VOLVO': 35}
#
# Lables for MODEL:
# {'1.6EL': 0, '3.2TL': 1, '3.5RL': 2, '300M': 3, '323 CONVERTIBLE': 4, '323Ci': 5, '323i': 6, '328Ci': 7, '328i': 8, '360 MODENA F1': 9, '456 MGT': 10, '456 MGTA': 11, '4RUNNER 4X4': 12, '528i': 13, '528i TOURING': 14, '540i': 15, '540i TOURING': 16, '550 MARANELLO': 17, '626': 18, '740i': 19, '740iL': 20, '750iL': 21, '9-3 TURBO': 22, '9-5 TURBO': 23, '9-5 WAGON TURBO': 24, '911 CARRERA': 25, '911 CARRERA 4': 26, 'A4': 27, 'A4 QUATTRO': 28, 'A6': 29, 'A6 AVANT QUATTRO': 30, 'A6 QUATTRO': 31, 'A8 QUATTRO': 32, 'ACCENT': 33, 'ACCORD': 34, 'ACCORD DX': 35, 'ACCORD EX/LX': 36, 'ALERO': 37, 'ALTIMA': 38, 'ASTRO AWD CARGO': 39, 'ASTRO AWD PASSENGER': 40, 'ASTRO CARGO': 41, 'ASTRO PASSENGER': 42, 'AVALON': 43, 'B3000': 44, 'B4000': 45, 'B4000 4X4': 46, 'BLAZER': 47, 'BLAZER 4X4': 48, 'BONNEVILLE': 49, 'BONNEVILLE #': 50, 'BOXSTER': 51, 'BOXSTER S': 52, 'C 230 KOMPRESSOR #': 53, 'C 280': 54, 'C 43 AMG': 55, 'C1500 SIERRA': 56, 'C1500 SILVERADO': 57, 'C1500 YUKON': 58, 'C1500 YUKON XL': 59, 'C2500 SIERRA': 60, 'C2500 SILVERADO': 61, 'C70 CONVERTIBLE TURBO': 62, 'C70 TURBO': 63, 'CABRIO': 64, 'CAMARO': 65, 'CAMRY': 66, 'CAMRY SOLARA': 67, 'CAMRY SOLARA CONVERTIBLE': 68, 'CARAVAN': 69, 'CARAVAN FFV': 70, 'CATERA': 71, 'CAVALIER': 72, 'CAVALIER BIFUEL': 73, 'CELICA': 74, 'CENTURY': 75, 'CHEROKEE 4X4': 76, 'CIRRUS': 77, 'CIVIC COUPE Si': 78, 'CIVIC COUPE SiR': 79, 'CIVIC CX/DX/LX/EX': 80, 'CLK 320': 81, 'CLK 320 CABRIOLET': 82, 'CLK 430': 83, 'CLK 430 CABRIOLET': 84, 'CONCORDE': 85, 'CONTINENTAL': 86, 'COROLLA': 87, 'CORVETTE': 88, 'COUGAR': 89, 'CR-V': 90, 'CROWN VICTORIA': 91, 'DAKOTA': 92, 'DAKOTA 4X4': 93, 'DEVILLE': 94, 'DISCOVERY SERIES II 4X4': 95, 'DURANGO 4X4': 96, 'DURANGO 5.9 R/T 4X4': 97, 'E 320': 98, 'E 320 4MATIC': 99, 'E 320 4MATIC WAGON': 100, 'E 320 WAGON': 101, 'E 430': 102, 'E 430 4MATIC': 103, 'E 55 AMG': 104, 'E150 CLUB WAGON': 105, 'E150 VAN': 106, 'E250 VAN': 107, 'ECHO': 108, 'ELANTRA': 109, 'ELANTRA WAGON': 110, 'ELDORADO': 111, 'ES 300': 112, 'ESCALADE 4X4': 113, 'ESCORT ZX2': 114, 'ESTEEM': 115, 'ESTEEM WAGON': 116, 'EUROVAN': 117, 'EUROVAN CAMPER': 118, 'EXPEDITION': 119, 'EXPEDITION 4X4': 120, 'EXPLORER': 121, 'EXPLORER 4X4': 122, 'EXPLORER OHV': 123, 'EXPLORER OHV 4X4': 124, 'EXPLORER SOHC': 125, 'EXPLORER SOHC 4X4': 126, 'F150': 127, 'F150 4X4': 128, 'FIREBIRD/FORMULA': 129, 'FIREFLY': 130, 'FOCUS SEDAN': 131, 'FOCUS WAGON': 132, 'FORESTER AWD': 133, 'FRONTIER': 134, 'FRONTIER 4X4': 135, 'FRONTIER V6': 136, 'FRONTIER V6 4X4': 137, 'G15/G25 CHEVY VAN': 138, 'G15/G25 SAVANA CARGO': 139, 'G1500/G2500 CHEVY EXPRESS': 140, 'G1500/G2500 SAVANA PASSENGER': 141, 'G20': 142, 'GOLF': 143, 'GOLF TDI DIESEL': 144, 'GRAND AM': 145, 'GRAND CARAVAN': 146, 'GRAND CARAVAN AWD': 147, 'GRAND CARAVAN FFV': 148, 'GRAND CHEROKEE 4X4': 149, 'GRAND MARQUIS': 150, 'GRAND PRIX': 151, 'GRAND PRIX #': 152, 'GRAND VITARA 4X4': 153, 'GS 300': 154, 'GS 400': 155, 'GTI': 156, 'HOMBRE': 157, 'HOMBRE 4X4': 158, 'I30': 159, 'IMPALA': 160, 'IMPREZA AWD': 161, 'IMPREZA WAGON AWD': 162, 'INSIGHT': 163, 'INTEGRA': 164, 'INTEGRA GSR/TYPE R': 165, 'INTREPID': 166, 'INTRIGUE': 167, 'JETTA': 168, 'JETTA TDI DIESEL': 169, 'JIMMY': 170, 'JIMMY 4X4': 171, 'K1500 SIERRA 4X4': 172, 'K1500 SILVERADO 4X4': 173, 'K1500 TAHOE 4X4': 174, 'K1500 YUKON 4X4': 175, 'LANOS': 176, 'LEGACY AWD': 177, 'LEGACY WAGON AWD': 178, 'LEGANZA': 179, 'LESABRE': 180, 'LHS': 181, 'LS': 182, 'LS 400': 183, 'LUMINA/MONTE CARLO': 184, 'LW WAGON': 185, 'LX 470': 186, 'M COUPE': 187, 'M ROADSTER': 188, 'M5': 189, 'MALIBU': 190, 'MAXIMA': 191, 'METRO': 192, 'MILLENIA': 193, 'MILLENIA #': 194, 'ML 320': 195, 'ML 430': 196, 'MONTANA': 197, 'MPV': 198, 'MUSTANG': 199, 'MUSTANG #': 200, 'MX-5 MIATA': 201, 'NAVIGATOR 4X4': 202, 'NEON': 203, 'NEW BEETLE': 204, 'NEW BEETLE TDI DIESEL': 205, 'NEW C1500 SUBURBAN': 206, 'NEW C1500 TAHOE': 207, 'NEW K1500 TAHOE 4X4': 208, 'NSX': 209, 'NUBIRA': 210, 'NUBIRA WAGON': 211, 'ODYSSEY': 212, 'PARK AVENUE': 213, 'PARK AVENUE #': 214, 'PASSAT': 215, 'PASS ...
#
# Lables for VEHICLE CLASS:
# {'COMPACT': 0, 'FULL-SIZE': 1, 'MID-SIZE': 2, 'MINICOMPACT': 3, 'MINIVAN': 4, 'PICKUP TRUCK - SMALL': 5, 'PICKUP TRUCK - STANDARD': 6, 'STATION WAGON - MID-SIZE': 7, 'STATION WAGON - SMALL': 8, 'SUBCOMPACT': 9, 'SUV': 10, 'TWO-SEATER': 11, 'VAN - CARGO': 12, 'VAN - PASSENGER': 13}
#
# Lables for TRANSMISSION:
# {'A3': 0, 'A4': 1, 'A5': 2, 'AS4': 3, 'AS5': 4, 'AS6': 5, 'M5': 6, 'M6': 7}
#
# Lables for FUEL:
# {'D': 0, 'E': 1, 'N': 2, 'X': 3, 'Z': 4}

# %%
def get_user_input():
    print("Enter the following details:")
    year = int(input("Enter the Year (Encoded): "))
    make = int(input("Enter the Make (Encoded): " ))
    model = int(input("Enter the Model (Encoded): "))
    vehicle_class = int(input("Enter the Vehicle Class (Encoded): "))
    engine_size = float(input("Enter the Engine Size (Encoded): "))
    cylinders = int(input("Enter the Cylinders (Encoded): "))
    transmission = int(input("Enter the Transmission (Encoded): "))
    fuel = float(input("Enter the Fuel  (Encoded): "))
    co2_emissions = float(input("Enter the CO2 Emissions (Encoded): "))
    # return year, make, model, vehicle_class, engine_size, cylinders, transmission, fuel_consumption, co2_emissions

# Convert to Numpy Array and reshape
    user_input_array = np.array([year, make, model, vehicle_class, engine_size, cylinders, transmission, fuel, co2_emissions]).reshape(1, -1)

    return user_input_array

#Get user input and make prediction
user_input = get_user_input()
prediction = model.predict(user_input)[0]
print(f"Predicted Fuel Consumption: {prediction:.2f} liters per 100 km")
# Out:
# Enter the following details:
# Predicted Fuel Consumption: 3.00 liters per 100 km

# %%
for col, le in label_encoders.items():
    print(f"Lables for {col}: {list(le.classes_)}")
# Out:
# Lables for MAKE: ['ACURA', 'AUDI', 'BMW', 'BUICK', 'CADILLAC', 'CHEVROLET', 'CHRYSLER', 'DAEWOO', 'DODGE', 'FERRARI', 'FORD', 'GMC', 'HONDA', 'HYUNDAI', 'INFINITI', 'ISUZU', 'JAGUAR', 'JEEP', 'KIA', 'LAND ROVER', 'LEXUS', 'LINCOLN', 'MAZDA', 'MERCEDES-BENZ', 'NISSAN', 'OLDSMOBILE', 'PLYMOUTH', 'PONTIAC', 'PORSCHE', 'SAAB', 'SATURN', 'SUBARU', 'SUZUKI', 'TOYOTA', 'VOLKSWAGEN', 'VOLVO']
# Lables for MODEL: ['1.6EL', '3.2TL', '3.5RL', '300M', '323 CONVERTIBLE', '323Ci', '323i', '328Ci', '328i', '360 MODENA F1', '456 MGT', '456 MGTA', '4RUNNER 4X4', '528i', '528i TOURING', '540i', '540i TOURING', '550 MARANELLO', '626', '740i', '740iL', '750iL', '9-3 TURBO', '9-5 TURBO', '9-5 WAGON TURBO', '911 CARRERA', '911 CARRERA 4', 'A4', 'A4 QUATTRO', 'A6', 'A6 AVANT QUATTRO', 'A6 QUATTRO', 'A8 QUATTRO', 'ACCENT', 'ACCORD', 'ACCORD DX', 'ACCORD EX/LX', 'ALERO', 'ALTIMA', 'ASTRO AWD CARGO', 'ASTRO AWD PASSENGER', 'ASTRO CARGO', 'ASTRO PASSENGER', 'AVALON', 'B3000', 'B4000', 'B4000 4X4', 'BLAZER', 'BLAZER 4X4', 'BONNEVILLE', 'BONNEVILLE #', 'BOXSTER', 'BOXSTER S', 'C 230 KOMPRESSOR #', 'C 280', 'C 43 AMG', 'C1500 SIERRA', 'C1500 SILVERADO', 'C1500 YUKON', 'C1500 YUKON XL', 'C2500 SIERRA', 'C2500 SILVERADO', 'C70 CONVERTIBLE TURBO', 'C70 TURBO', 'CABRIO', 'CAMARO', 'CAMRY', 'CAMRY SOLARA', 'CAMRY SOLARA CONVERTIBLE', 'CARAVAN', 'CARAVAN FFV', 'CATERA', 'CAVALIER', 'CAVALIER BIFUEL', 'CELICA', 'CENTURY', 'CHEROKEE 4X4', 'CIRRUS', 'CIVIC COUPE Si', 'CIVIC COUPE SiR', 'CIVIC CX/DX/LX/EX', 'CLK 320', 'CLK 320 CABRIOLET', 'CLK 430', 'CLK 430 CABRIOLET', 'CONCORDE', 'CONTINENTAL', 'COROLLA', 'CORVETTE', 'COUGAR', 'CR-V', 'CROWN VICTORIA', 'DAKOTA', 'DAKOTA 4X4', 'DEVILLE', 'DISCOVERY SERIES II 4X4', 'DURANGO 4X4', 'DURANGO 5.9 R/T 4X4', 'E 320', 'E 320 4MATIC', 'E 320 4MATIC WAGON', 'E 320 WAGON', 'E 430', 'E 430 4MATIC', 'E 55 AMG', 'E150 CLUB WAGON', 'E150 VAN', 'E250 VAN', 'ECHO', 'ELANTRA', 'ELANTRA WAGON', 'ELDORADO', 'ES 300', 'ESCALADE 4X4', 'ESCORT ZX2', 'ESTEEM', 'ESTEEM WAGON', 'EUROVAN', 'EUROVAN CAMPER', 'EXPEDITION', 'EXPEDITION 4X4', 'EXPLORER', 'EXPLORER 4X4', 'EXPLORER OHV', 'EXPLORER OHV 4X4', 'EXPLORER SOHC', 'EXPLORER SOHC 4X4', 'F150', 'F150 4X4', 'FIREBIRD/FORMULA', 'FIREFLY', 'FOCUS SEDAN', 'FOCUS WAGON', 'FORESTER AWD', 'FRONTIER', 'FRONTIER 4X4', 'FRONTIER V6', 'FRONTIER V6 4X4', 'G15/G25 CHEVY VAN', 'G15/G25 SAVANA CARGO', 'G1500/G2500 CHEVY EXPRESS', 'G1500/G2500 SAVANA PASSENGER', 'G20', 'GOLF', 'GOLF TDI DIESEL', 'GRAND AM', 'GRAND CARAVAN', 'GRAND CARAVAN AWD', 'GRAND CARAVAN FFV', 'GRAND CHEROKEE 4X4', 'GRAND MARQUIS', 'GRAND PRIX', 'GRAND PRIX #', 'GRAND VITARA 4X4', 'GS 300', 'GS 400', 'GTI', 'HOMBRE', 'HOMBRE 4X4', 'I30', 'IMPALA', 'IMPREZA AWD', 'IMPREZA WAGON AWD', 'INSIGHT', 'INTEGRA', 'INTEGRA GSR/TYPE R', 'INTREPID', 'INTRIGUE', 'JETTA', 'JETTA TDI DIESEL', 'JIMMY', 'JIMMY 4X4', 'K1500 SIERRA 4X4', 'K1500 SILVERADO 4X4', 'K1500 TAHOE 4X4', 'K1500 YUKON 4X4', 'LANOS', 'LEGACY AWD', 'LEGACY WAGON AWD', 'LEGANZA', 'LESABRE', 'LHS', 'LS', 'LS 400', 'LUMINA/MONTE CARLO', 'LW WAGON', 'LX 470', 'M COUPE', 'M ROADSTER', 'M5', 'MALIBU', 'MAXIMA', 'METRO', 'MILLENIA', 'MILLENIA #', 'ML 320', 'ML 430', 'MONTANA', 'MPV', 'MUSTANG', 'MUSTANG #', 'MX-5 MIATA', 'NAVIGATOR 4X4', 'NEON', 'NEW BEETLE', 'NEW BEETLE TDI DIESEL', 'NEW C1500 SUBURBAN', 'NEW C1500 TAHOE', 'NEW K1500 TAHOE 4X4', 'NSX', 'NUBIRA', 'NUBIRA WAGON', 'ODYSSEY', 'PARK AVENUE', 'PARK AVENUE #', 'PASSAT', 'PASSAT WAGON', 'PATHFINDER 4X4', 'PRELUDE', 'PROTEGE', 'PROWLER', 'PT CRUISER', 'QUEST', 'QX4 4X4', 'RAM 1500', 'RAM 1500 4X4', 'RAM 1500 VAN', 'RAM 1500 WAGON', 'RAM 2500 VAN', 'RAM 2500 VAN NGV', 'RAM 2500 WAGON', 'RANGE ROVER 4X4', 'RANGER', 'RANGER 4X4', 'RAV4', 'RAV4 4X4', 'RAV4 SOFT TOP', 'RAV4 SOFT TOP 4X4', 'REGAL', 'REGAL #', 'RODEO 4X4', 'RX 300', 'RX 300 4X4', 'S 430', 'S 500', 'S-TYPE V6', 'S-TYPE V8', 'S10', 'S10 4X4', 'S2000', 'S4 QUATTRO', 'S70', 'S70 AWD TURBO', 'S70 GLT TURBO', 'S70 T5 TURBO', 'S80 2.9', 'S80 T-6', 'SAFARI CARGO', 'SAFARI CARGO AWD', 'SAFARI PASSENGER', 'SAFARI PASSENGER AWD', 'SC', 'SC #', 'SEBRING', 'SEBRING CONVERTIBLE', 'SEPHIA', 'SEVILLE', 'SIENNA', 'SILHOUETTE', 'SL', 'SL #', 'SL 500', 'SL 600', 'SLK 230 KOMPRESSOR #', 'SONATA 2.4L', 'SONATA 2.5L', 'SONOMA', 'SONOMA 4X4', 'SPORTAGE 4X4', 'SUNFIRE', 'SW WAGON #', 'SWIFT', 'TACOMA', 'TACOMA 4X4', 'TAURUS', 'TAURUS #', 'TAURUS WAGON', 'TAURUS WAGON #', 'TI ...
# Lables for VEHICLE CLASS: ['COMPACT', 'FULL-SIZE', 'MID-SIZE', 'MINICOMPACT', 'MINIVAN', 'PICKUP TRUCK - SMALL', 'PICKUP TRUCK - STANDARD', 'STATION WAGON - MID-SIZE', 'STATION WAGON - SMALL', 'SUBCOMPACT', 'SUV', 'TWO-SEATER', 'VAN - CARGO', 'VAN - PASSENGER']
# Lables for TRANSMISSION: ['A3', 'A4', 'A5', 'AS4', 'AS5', 'AS6', 'M5', 'M6']
# Lables for FUEL: ['D', 'E', 'N', 'X', 'Z']

# %%
# identify categorical columns
categorical_columns = ['MAKE', 'MODEL', 'VEHICLE CLASS', 'TRANSMISSION', 'FUEL']

# DEcode only categorical values
decode_values = {
    col: label_encoders[col].inverse_transform([int(user_input [0, i])])[0]
    for i, col in enumerate(categorical_columns, start=1) # skip year (index 0)
}

# Print user inputs in original form
print("\nUser Inputs (Original Values):")
for col, val in decode_values.items():
    print(f"{col}: {val}")  

# Print predicted fuel consumption
print(f"\nPredicted Fuel Consumption: {prediction:.2f} liters per 100 km")
# Out:
# User Inputs (Original Values):
# MAKE: AUDI
# MODEL: 3.2TL
# VEHICLE CLASS: FULL-SIZE
# TRANSMISSION: A4
# FUEL: Z
#
# Predicted Fuel Consumption: 3.00 liters per 100 km
